# %% [markdown]
# <!-- INDICE  -->
# <p style='text-align:center;background-color:#f4c272;color:#008b8b;font-weight:800;font-size:35px;border-radius:10px 10px 0 0;'>Indice:</p>
#
# <!-- FONDO -->
# <div style='background-color:#008b8b;padding:15px;margin-top:-35px;border-radius:0 0 10px 10px'>
#
# <!-- DÍA 1 TITULO -->
# <p style='font-size:25px;font-weight:800;margin-bottom:-10px'><a href='#uni' style='color:#2efbcd;'>Univariate Plotting with Pandas </p>
#
# <!-- LISTA DE TEMAS -->
# <ol>
#     <a href='#uni_1' style='font-weight:500;font-size:18px;color:#4a235a'><li>Bar Charts and Categorical Data</li></a>
#     <a href='#uni_2' style='font-weight:500;font-size:18px;color:#4a235a'><li>Line Charts</li></a>
#     <a href='#uni_3' style='font-weight:500;font-size:18px;color:#4a235a'><li>Area Charts</li></a>
#     <a href='#uni_4' style='font-weight:500;font-size:18px;color:#4a235a'><li>Invertal Data</li></a>
#     <a href='#uni_5' style='font-weight:500;font-size:18px;color:#4a235a'><li>Histograms</li></a>
# </ol>
#
#
# <!-- DÍA 2 TITULO -->
# <p style='font-size:25px;font-weight:800;margin-bottom:-10px'><a href='#biv' style='color:#2efbcd;'>Bivariate plotting with Pandas
#
# <!-- LISTA DE TEMAS -->
# <ol>
#     <a href='#uni_1' style='font-weight:500;font-size:18px;color:#4a235a'><li>Bar Charts and Categorical Data</li></a>
#
#
# <!-- FUENTES -->
# <p style='font-weight:700;margin-bottom:5px;font-size:20px;color:#2efbcd;'> FUENTES </p>
#
# <!-- LISTA DE FUENTES -->
# <ul>
#     <a href='https://www.kaggle.com/code/residentmario/welcome-to-data-visualization' style='color:#4a235a;font-weight:700;'><li>Welcome to data visualization</li></a>

# %% [markdown]
# #
# ---
# <p id='uni' style='padding:15px;background-color:#4a235a;text-align:center;font-size:30px;font-weight:800;border-radius:20px;color:#2efbcd'> Univariate Plotting with Pandas

# %%
# Importamos las librerias 
import pandas as pd

# %%
# Cargamos el DataFrame
reviews = pd.read_csv('../datasets/winemag-data_first150k.csv',index_col=0)

# Revisamos que el DataFrame haya cargado correctamente
reviews.head(3)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
#
#          region_1 region_2             variety                   winery
# 0     Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1            Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2  Knights Valley   Sonoma     Sauvignon Blanc                 Macauley

# %% [markdown]
# <p id='uni_1' style='text-align:center;background-color:#f4c272;color:#008b8b;font-weight:800;font-size:25px;border-radius:15px;padding:10px;'>Bar Charts and Categorical Data</p>

# %% [markdown]
# El <b style='color:#2efbcd'>Gráfico de Barras</b> es el más común y simple de todos, muestran categorías como numeros, por ejemplo:
# - La cantidad de huevos consumidos en el desayuno (una categoría).
#
# O en nuestro caso:
# - Producción de Vino en distintas provincias del mundo.

# %%
reviews['province'].value_counts().head(10).plot.bar(color=['blue','orange','green','red','magenta','brown','pink','grey','yellow','cyan']);

# %% [markdown]
# Con el gráfico podemos deducir que <b style='color:#44BEE4'>California</b> produce con gran diferencia más <b style='color:brown'>vino</b> que los demás. Deberíamos preguntarnos cuál es el porcentaje que toma, porque este gráfico no nos dice nada más que números.

# %% [markdown]
# > <b style='font-size:20px'>Consejo:</b>
# >
# > - dataframe.shape = [Filas, Columnas]
# >
# > - dataframe.size = [Filas * Columnas]

# %%
(reviews['province'].value_counts().head(10) / reviews['province'].size).plot.bar(color=['blue','orange','green','red','magenta','brown','pink','grey','yellow','cyan']);

# %% [markdown]
# Ahora sabemos que <b style='color:#44bee4'>California</b> produce casi el <b style='color:#44bee4'>30%</b> de todo el vino producido en el mundo.
#
# > <b style='font-size:20px'>Consejo:</b>
# >
# > Los <b style='color:#2efbcd'>Gráficos de Barra</b> son muy utiles cuando quieres representar la <b style='color:#44bee4'>altura</b> con algún <b style='color:#44bee4'>número</b>; De igual forma cada <b style='color:#ffcc00'>columna</b> puede representar lo que sea mientras sea <b style='color:#ffcc00'>categorico</b>.

# %% [markdown]
# En valores <b style='color:#44bee4'>nominales</b> (como este caso), no es necesario ordenar los valores. Pero en casos <b style='color:#ffcc00'>ordinales</b> sí es necesario para mejor entendimiento.
#
# Por ejemplo:

# %%
reviews['points'].value_counts().sort_index().plot.bar(color=['blue','orange','green','red','purple','brown','pink','grey','yellow','cyan','darkblue']);

# %% [markdown]
# <p id='uni_2' style='text-align:center;background-color:#f4c272;color:#008b8b;font-weight:800;font-size:25px;border-radius:15px;padding:10px;'>Line Charts</p>

# %% [markdown]
# <p id='uni_1' style='text-align:center;background-color:darkred;color:#ffcc00;font-weight:800;font-size:25px;border-radius:15px;padding:10px;'>INCOMPLETO POR FALLAS DE GIT QUE ME BORRABA TODO 😭😭</p>

# %% [markdown]
# #
# ---
# <p style='padding:15px;background-color:#4a235a;text-align:center;font-size:30px;font-weight:800;border-radius:20px;color:#2efbcd'> Bivariate plotting with pandas

# %%
import pandas as pd
reviews = pd.read_csv('../datasets/winemag-data_first150k.csv',index_col=0)
reviews.head(2)
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %% [markdown]
# ### **Scatter Plot**

# %%
reviews.shape
# Out:
# (150930, 10)

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price',y='points');

# %% [markdown]
# ### Hexplot

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price',y='points',gridsize=15)
# Out:
# <Axes: xlabel='price', ylabel='points'>

# %% [markdown]
# ### Stacked Plots

# %%
wine_counts = pd.read_csv('../datasets/top-five-wine-score-counts.csv', index_col=0)
wine_counts.head()
# Out:
#         Bordeaux-style Red Blend  Cabernet Sauvignon  Chardonnay  Pinot Noir  \
# points
# 80                           5.0                87.0        68.0        36.0
# 81                          18.0               159.0       150.0        83.0
# 82                          72.0               435.0       517.0       295.0
# 83                          95.0               570.0       669.0       346.0
# 84                         268.0               923.0      1146.0       733.0
#
#         Red Blend
# points
# 80           72.0
# 81          107.0
# 82          223.0
# 83          364.0
# 84          602.0

# %%
# Let's start with some Stacked Plots

wine_counts.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='points'>

# %%
# AREA PLOT

wine_counts.plot.area()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# ### Line Charts

# %%
wine_counts.plot.line()
# Out:
# <Axes: xlabel='points'>

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. A scatter plot or hex plot is good for what two types of data?
#     - `Ordinal categorical and interval data`
#
# 2. What type of data makes sense to show in a stacked bar chart, but not in a bivariate line chart?
#     - `Nominal categorical`
#
# 3. What type of data makes sense to show in a bivariate line chart, but not in a stacked bar chart?
#     - `Interval data`
#
# 4. Suppose we create a scatter plot but find that due to the large number of points it's hard to interpret. What are two things we can do to fix this issue?
#     -
